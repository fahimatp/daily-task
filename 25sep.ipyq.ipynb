# %%
fruits=["apple","banana","cherry"]
if "l" in "apple":print("yes")
# Out:
# yes

# %%
print("yes") if "l" in "apple" else print("no")
# Out:
# yes

# %%
a=10
b=20
c=15
print("a>") if a>b and a>c else print("b>") if b>c and b>a else print("c>")
# Out:
# b>

# %%
fruits=["apple","banana","kiwi","mango"]
y=[i for i in fruits if "a" in i]

# %%
y
# Out:
# ['apple', 'banana', 'mango']

# %%
n=[23,45,22,45,23,46]
odd=[i for i in n if i%2!=0]

# %%
odd
# Out:
# [23, 45, 45, 23]

# %%
fruits=["app","banana","cherry","kiwi","app","mango"]
f=["apple"if i=="app" else i for i in fruits]

# %%
f
# Out:
# ['apple', 'banana', 'cherry', 'kiwi', 'apple', 'mango']

# %%
salary=[12,34,45,23,234,435,23,453]
r=["high salary" if i>100 else "low salary" for i in salary]

# %%
r
# Out:
# ['low salary',
#  'low salary',
#  'low salary',
#  'low salary',
#  'high salary',
#  'high salary',
#  'low salary',
#  'high salary']

# %%
x=["apple","banana","kiwi","mango"]
x.sort()

# %%
x
# Out:
# ['apple', 'banana', 'kiwi', 'mango']

# %%
x=["apple","banana","kiwi","mango"]
x.sort(reverse=True)

# %%
x
# Out:
# ['mango', 'kiwi', 'banana', 'apple']

# %%
a=[23,34,45]
b=[34,45,34]

# %%
a+b
# Out:
# [23, 34, 45, 34, 45, 34]

# %%
a=[23,34,45,34]
for i in b:
    a.append(i)

# %%
a
# Out:
# [23, 34, 45, 34, 34, 45, 34]

# %%
x=["apple","banana","kiwi","mango"]
def lastchar(n):
    return len(n)
x.sort(key=lastchar)

# %%
x
# Out:
# ['kiwi', 'apple', 'mango', 'banana']

# %%
x=["apple","banana","kiwi","mango"]
def lastchar(n):
    return n[-1]
x.sort(key=lastchar)

# %%
x
# Out:
# ['banana', 'apple', 'kiwi', 'mango']

# %%
num=[12,34,45,23,234,431,23,453]
def lastchar(n):
    n=str(n)
    return n[-1]
num.sort(key=lastchar)

# %%
num
# Out:
# [431, 12, 23, 23, 453, 34, 234, 45]
