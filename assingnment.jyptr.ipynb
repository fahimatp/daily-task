# %%
name="fahima"
print(name)
# Out:
# fahima

# %%
print(name[0])
# Out:
# f

# %%
print(name[-1])
# Out:
# a

# %%
print(len(name))
# Out:
# 6

# %%
students=["anu","binu","celine","devu","eshan"]
print(students[0])
# Out:
# anu

# %%
print(students[-1])
# Out:
# eshan

# %%
fruits=["banana","mango","apple","orange","grapes"]
print('apple exists in the list')
# Out:
# apple exists in the list
