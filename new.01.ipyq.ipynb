# %%
x=["apple","banana","cherry"]
x.append("orange")

# %%
x
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
x.insert(2,"red")

# %%
x
# Out:
# ['apple', 'banana', 'red', 'cherry', 'orange']

# %%
x=["mango","pineapple","green"]
y=["red","black"]
x.extend(y)

# %%
x
# Out:
# ['mango', 'pineapple', 'green', 'red', 'black']

# %%
x.remove("pineapple")

# %%
x
# Out:
# ['mango', 'green', 'red', 'black']

# %%
x.pop(1)
# Out:
# 'green'

# %%
x.pop()
# Out:
# 'black'

# %%
del x[0]

# %%
x
# Out:
# ['red']

# %%
x.clear()

# %%
x
# Out:
# []

# %%
x="red"
x.upper()
# Out:
# 'RED'

# %%
x.lower()
# Out:
# 'red'

# %%
x=" my name is fahima "
x.strip()
# Out:
# 'my name is fahima'

# %%
x
# Out:
# ' my name is fahima '

# %%
x=" my name is fahima "
x.lstrip()
# Out:
# 'my name is fahima '

# %%
x=" my name is fahima "
x.rstrip()
# Out:
# ' my name is fahima'

# %%
x="  iam fahima"
x.split("  ")
# Out:
# ['', 'iam fahima']

# %%
fullname="elhan eshan"

# %%
fullname.split()
# Out:
# ['elhan', 'eshan']

# %%
[fnme,lnme]=fullname.split(" ")

# %%
fnme
# Out:
# 'elhan'

# %%
lnme
# Out:
# 'eshan'

# %%
name="fahima"
age=23
x=f"my name is fahima and my age is {age}"

# %%
x
# Out:
# 'my name is fahima and my age is 23'

# %%
name="fahima"
age=23
salary=150000.05

# %%
print(f"name is {name} age {age} salary is {salary:.1f}")
# Out:
# name is fahima age 23 salary is 150000.0

# %%
x="hello my girls\'s"

# %%
x
# Out:
# "hello my girls's"

# %%
x="the red bag and\n the  black bag"

# %%
print(x)
# Out:
# the red bag and
#  the  black bag

# %%
x="hello\rfahima's world"

# %%
print(x)
# Out:
# fahima's world

# %%
x="hello\tfahima's world"

# %%
print(x)
# Out:
# hello	fahima's world

# %%
name="fahima bushra"
name.replace("fahima","elhan")
# Out:
# 'elhan bushra'
